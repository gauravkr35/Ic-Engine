# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_excel("dataPoint.xlsx")
# Out:
# C:\Users\gaura\AppData\Roaming\Python\Python311\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
data
# Out:
#          Fuel Type   RPM  Power(W)  Thermal Efficiency(%)  \
# 0   Gasoline(100%)  1500      1050                 0.2000
# 1   Gasoline(100%)  1600      1090                 0.2080
# 2   Gasoline(100%)  1700      1130                 0.2160
# 3   Gasoline(100%)  1800      1160                 0.2220
# 4   Gasoline(100%)  1900      1180                 0.2260
# 5   Gasoline(100%)  2000      1200                 0.2300
# 6   Gasoline(100%)  2100      1292                 0.2380
# 7   Gasoline(100%)  2200      1384                 0.2460
# 8   Gasoline(100%)  2300      1484                 0.2540
# 9   Gasoline(100%)  2400      1592                 0.2620
# 10  Gasoline(100%)  2500      1700                 0.2700
# 11           E 10%  1500      1170                 0.2200
# 12           E 10%  1600      1198                 0.2240
# 13           E 10%  1700      1226                 0.2280
# 14           E 10%  1800      1240                 0.2320
# ...

# %%
avg_efficiency = data.groupby(["Fuel Type","RPM"])["Thermal Efficiency(%)"].mean().reset_index()


best_combination = avg_efficiency.loc[avg_efficiency["Thermal Efficiency(%)"].idxmax()]

print("\n🔹 Best Parameter Combination for Maximum Efficiency 🔹")
print(best_combination)
# Out:
# 🔹 Best Parameter Combination for Maximum Efficiency 🔹
# Fuel Type                E 40%
# RPM                       2500
# Thermal Efficiency(%)     0.37
# Name: 43, dtype: object
